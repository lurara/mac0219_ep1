# %% [markdown]
# # <font style="background-color:#abebc6">EP1  - Cálculo do Conjunto de Mandelbrot em Paralelo com Pthreads e OpenMP
#
# ## MAC0219 - Programação Concorrente e Paralela
#
# Name: Débora D'Angelo Reina de Araujo NUSP: 11221668
#
# Name: Eike Souza da Silva NUSP: 4618653
#
# Name: Julia Leite NUSP: 11221797
#
# Name: Lara Ayumi Nagamatsu NUSP: 9910568

# %% [markdown]
# ## Programa Sequencial

# %%
using Plots
entrada = [16, 32, 64, 128, 256, 512, 1024, 2048, 4096]
tempomedio_fp = [0.292, 0.08513, 0.1022, 0.332, 0.3923, 0.448, 0.7917, 1.827, 5.6391]
ic_fp = [0.103,0.00880,0.0147,0.104,0.0862,0.103,0.0831,0.103,0.0837]

p = plot(entrada, tempomedio_fp, title = "Sequencial Full Picture", label = ["input x t(s)"], lw = 3)
plot!(p, entrada, ic_fp, label = ["IC"])

xlabel!("Tamanho da entrada")
ylabel!("tempo médio(s)")

# %%
tempomedio_sv = [0.1503, 0.347, 0.254, 0.1994, 0.3806, 0.907, 2.198, 6.4955, 24.0289]
ic_sv = [0.0160,0.140,0.104,0.0184,0.0881,0.138,0.108,0.0747,0.0493]
p = plot(entrada, tempomedio_sv, title = "Sequencial Seahorse Valley", label = ["input x t(s)"], lw = 3)
plot!(p, entrada, ic_sv, label = ["IC"])
xlabel!("Tamanho da entrada")
ylabel!("tempo médio(s)")

# %%
tempomedio_ev = [0.350, 0.0904, 0.1412, 0.2576, 0.2701, 0.8811, 2.293, 6.1137, 22.8314]
ic_ev = [0.104,0.0106,0.0250,0.0310,0.0143,0.0928,0.139,0.0621,0.0997]
p = plot(entrada, tempomedio_ev, title = "Sequencial Elephant Valley", label = ["input x t(s)"], lw = 3)
plot!(p, entrada, ic_ev, label = ["IC"])
xlabel!("Tamanho da entrada")
ylabel!("tempo médio(s)")

# %%
tempomedio_tsv = [0.14337, 0.270, 0.258,0.343,0.3996,1.0285,2.508,7.1014,26.8612]
ic_tsv = [0.00203,0.113,0.113,0.113,0.0855,0.0737,0.137,0.0656,0.0556]
p = plot(entrada, tempomedio_tsv, title = "Sequencial Triple Spiral Valley",label = ["input x t(s)"], lw = 3)
plot!(p, entrada, ic_tsv, label = ["IC"])
xlabel!("Tamanho da entrada")
ylabel!("tempo médio(s)")

# %% [markdown]
# ## Programa com Pthreads

# %%
tempomedio_fpp1 = [0.10991,0.0884,0.0833,0.1209,0.1788,0.4252,0.6387,1.8923,6.0967]
ic_fpp1 = [0.00958,0.0184,0.0141,0.0140,0.0103,0.0830,0.0660,0.0943,0.0937]
p = plot(entrada, tempomedio_fpp1, title ="Full Picture Pthreads/Thread = 1",label = ["input x t(s)"], lw = 3)
plot!(p, entrada, ic_fpp1, label = ["IC"])
xlabel!("Tamanho da entrada")
ylabel!("tempo médio(s)")

# %%
tempomedio_svp1 = [0.2391,0.1174,0.07416,0.3293,0.3703,0.8644,2.118,6.3648,24.1390]
ic_svp1 = [0.0938,0.0510,0.00828,0.0768,0.0907,0.0870,0.119,0.0672,0.0745]
p = plot(entrada, tempomedio_svp1, title ="Seahorse Valley Pthreads/Thread = 1",label = ["input x t(s)"],  lw = 3)
plot!(p, entrada, ic_svp1, label = ["IC"])
xlabel!("Tamanho da entrada")
ylabel!("tempo médio(s)")

# %%
tempomedio_evp1 = [0.1026,0.06331,0.1847,0.1880,0.3913,0.5996,2.0165,6.1919,23.0040]
ic_evp1 = [0.0156,0.00886,0.0835,0.0500,0.0827,0.0570,0.0860,0.0549,0.0473]
p = plot(entrada, tempomedio_evp1, title ="Elephant Valley Pthreads/Thread = 1",label = ["input x t(s)"], lw = 3)
plot!(p, entrada, ic_evp1, label = ["IC"])
xlabel!("Tamanho da entrada")
ylabel!("tempo médio(s)")

# %%
tempomedio_tsvp1 = [0.3194,0.0642,0.0936,0.1425,0.3944,0.897,2.2278,7.0492,27.0656]
ic_tsvp1 = [0.0872,0.0100,0.0143,0.0107,0.0773,0.104,0.0606,0.0488, 0.0541]
p = plot(entrada, tempomedio_tsvp1, title ="Triple Spiral Valley Pthreads/Thread = 1",label = ["input x t(s)"], lw = 3)
plot!(p, entrada, ic_tsvp1, label = ["IC"])
xlabel!("Tamanho da entrada")
ylabel!("tempo médio(s)")

# %%
tempomedio_fpp2 = [0.1490,0.0736,0.1278,0.3179,0.2380,0.2680,0.5515,1.4762,4.4446]
ic_fpp2 = [0.0169,0.0122,0.0170,0.0975,0.0387,0.0102,0.0657,0.0818,0.0573]
p = plot(entrada, tempomedio_fpp2, title ="Full Picture Pthreads/Thread = 2",label = ["input x t(s)"], lw = 3)
plot!(p, entrada, ic_fpp2, label = ["IC"])
xlabel!("Tamanho da entrada")
ylabel!("tempo médio(s)")

# %%
tempomedio_svp2 = [0.1816,0.0915,0.0768,0.1619,0.2334,0.5310,1.3064,4.4072,15.0731]
ic_svp2 = [0.0570,0.0157,0.0104,0.0160,0.0139,0.0884,0.0846,0.0965,0.0530]
p = plot(entrada, tempomedio_svp2, title ="Seahorse Valley Pthreads/Thread = 2",label = ["input x t(s)"],  lw = 3)
plot!(p, entrada, ic_svp2, label = ["IC"])
xlabel!("Tamanho da entrada")
ylabel!("tempo médio(s)")

# %%
tempomedio_evp2 = [0.1233,0.06425,0.2131,0.2670,0.3463,0.5049,1.433,4.014,15.0731]
ic_evp2 = [0.0189,0.00880,0.0760,0.0824,0.0784,0.0618,0.129,0.101,0.0576]
p = plot(entrada, tempomedio_evp2, title ="Elephant Valley Pthreads/Thread = 2",label = ["input x t(s)"], lw = 3)
plot!(p, entrada, ic_evp2, label = ["IC"])
xlabel!("Tamanho da entrada")
ylabel!("tempo médio(s)")

# %%
tempomedio_tsvp2 = [0.09756,0.2016,0.07952,0.1595,0.3545,0.5377,1.5218,4.6571,13.20083]
ic_tsvp2 = [0.00350,0.0892,0.00865,0.0185,0.0900,0.0678,0.0847,0.0898,0.115]
p = plot(entrada, tempomedio_tsvp2, title ="Triple Spiral Valley Pthreads/Thread = 2",label = ["input x t(s)"], lw = 3)
plot!(p, entrada, ic_tsvp2, label = ["IC"])
xlabel!("Tamanho da entrada")
ylabel!("tempo médio(s)")

# %%
tempomedio_fpp4 = [0.09788,0.2371,0.07201,0.3351,0.3203,0.3385,0.5957,1.3715,4.2627]
ic_fpp4 = [0.00386,0.0785,0.00968,0.0945,0.0865,0.0835,0.0805,0.0807,0.0913]
p = plot(entrada, tempomedio_fpp4, title ="Full Picture Pthreads/Thread = 4",label = ["input x t(s)"], lw = 3)
plot!(p, entrada, ic_fpp4, label = ["IC"])
xlabel!("Tamanho da entrada")
ylabel!("tempo médio(s)")

# %%
tempomedio_svp4 = [0.1972,0.0762,0.2408,0.1206,0.1646,0.3196,1.1009,2.737,9.2620]
ic_svp4 = [0.0234,0.0112,0.0712,0.0142,0.0138,0.0179,0.0623,0.102,0.0402]
p = plot(entrada, tempomedio_svp4, title ="Seahorse Valley Pthreads/Thread = 4",label = ["input x t(s)"],  lw = 3)
plot!(p, entrada, ic_svp4, label = ["IC"])
xlabel!("Tamanho da entrada")
ylabel!("tempo médio(s)")

# %%
tempomedio_evp4 = [0.3212,0.0658,0.0663,0.2704,0.3034,0.3175,1.008,2.5467,8.7702]
ic_evp4 = [0.0845,0.0108,0.00812,0.0934,0.0731,0.0151,0.127,0.0931,0.0827]
p = plot(entrada, tempomedio_evp4, title ="Elephant Valley Pthreads/Thread = 4",label = ["input x t(s)"], lw = 3)
plot!(p, entrada, ic_evp4, label = ["IC"])
xlabel!("Tamanho da entrada")
ylabel!("tempo médio(s)")

# %%
tempomedio_tsvp4 = [0.10035,0.208,0.2132,0.1542,0.3302, 0.3043,1.0618,2.8396,9.6468]
ic_tsvp4 = [0.00270,0.101,0.0791,0.0198,0.0937,0.0181,0.0989,0.0853,0.0796]
p = plot(entrada, tempomedio_tsvp4, title ="Triple Spiral Valley Pthreads/Thread = 4",label = ["input x t(s)"], lw = 3)
plot!(p, entrada, ic_tsvp4, label = ["IC"])
xlabel!("Tamanho da entrada")
ylabel!("tempo médio(s)")

# %%
tempomedio_fpp8 = [0.10527,0.06336,0.259,0.11387, 0.3068,0.4095, 0.5301, 1.255, 4.1017]
ic_fpp8 = [0.00242,0.00403,0.105,0.00994,0.0784,0.0989,0.0765,0.113,0.0732]
p = plot(entrada, tempomedio_fpp8, title ="Full Picture Pthreads/Thread = 8",label = ["input x t(s)"], lw = 3)
plot!(p, entrada, ic_fpp8, label = ["IC"])
xlabel!("Tamanho da entrada")
ylabel!("tempo médio(s)")

# %%
tempomedio_svp8 = [0.2827,0.06435,0.0799,0.2774,0.1636,0.3724,0.7328,1.9507,6.0755]
ic_svp8 = [0.0845,0.00925,0.0126,0.0780,0.0158,0.0876,0.0876,0.0851,0.0717]
p = plot(entrada, tempomedio_svp8, title ="Seahorse Valley Pthreads/Thread = 8",label = ["input x t(s)"],  lw = 3)
plot!(p, entrada, ic_svp8, label = ["IC"])
xlabel!("Tamanho da entrada")
ylabel!("tempo médio(s)")

# %%
tempomedio_evp8 = [0.1723,0.06513,0.06353,0.1620,0.3312,0.3703,0.6634,1.9634,5.9220]
ic_evp8 = [0.1723,0.00465,0.00808,0.0167,0.0881,0.0736,0.0951,0.0915,0.0984]
p = plot(entrada, tempomedio_evp8, title ="Elephant Valley Pthreads/Thread = 8",label = ["input x t(s)"], lw = 3)
plot!(p, entrada, ic_evp8, label = ["IC"])
xlabel!("Tamanho da entrada")
ylabel!("tempo médio(s)")

# %%
tempomedio_tsvp8 = [0.2097,0.1033,0.2058,0.1723,0.1800,0.22410,0.7194,2.080,6.338]
ic_tsvp8 = [0.0295,0.0197,0.0911,0.0460,0.0189,0.00999,0.0784,0.131,0.137]
p = plot(entrada, tempomedio_tsvp8, title ="Triple Spiral Valley Pthreads/Thread = 8",label = ["input x t(s)"], lw = 3)
plot!(p, entrada, ic_tsvp8, label = ["IC"])
xlabel!("Tamanho da entrada")
ylabel!("tempo médio(s)")

# %%
tempomedio_fpp16 = [0.1173,0.233,0.1012,0.1110,0.13520,0.2749,0.4318,1.0821,3.5195]
ic_fpp16 = [0.0137,0.111,0.0151,0.0146,0.00693,0.0417,0.0588,0.0712,0.0895]
p = plot(entrada, tempomedio_fpp16, title ="Full Picture Pthreads/Thread = 16",label = ["input x t(s)"], lw = 3)
plot!(p, entrada, ic_fpp16, label = ["IC"])
xlabel!("Tamanho da entrada")
ylabel!("tempo médio(s)")

# %%
tempomedio_svp16 = [0.1874,0.06714,0.05647,0.1420,0.3340,0.2341,0.5576,1.512,4.5531]
ic_svp16 = [0.0636,0.00875,0.00159,0.0197,0.0958,0.0118,0.0731,0.106,0.0534]
p = plot(entrada, tempomedio_svp16, title ="Seahorse Valley Pthreads/Thread = 16",label = ["input x t(s)"],  lw = 3)
plot!(p, entrada, ic_svp16, label = ["IC"])
xlabel!("Tamanho da entrada")
ylabel!("tempo médio(s)")

# %%
tempomedio_evp16 = [0.1371,0.06075,0.2119,0.10224,0.3310,0.3558,0.5325,1.4877,4.5307]
ic_evp16 = [0.0199,0.00437,0.0869,0.00454,0.0817,0.0738,0.0791,0.0863,0.0746]
p = plot(entrada, tempomedio_evp16, title ="Elephant Valley Pthreads/Thread = 16",label = ["input x t(s)"], lw = 3)
plot!(p, entrada, ic_evp16, label = ["IC"])
xlabel!("Tamanho da entrada")
ylabel!("tempo médio(s)")

# %%
tempomedio_tsvp16 = [0.2952,0.1506,0.0741,0.2407,0.1761,0.3553,0.5864,1.512,4.6675]
ic_tsvp16 = [0.0790,0.0722,0.0124,0.0651,0.0162,0.0814,0.0617,0.120,0.0917]
p = plot(entrada, tempomedio_tsvp16, title ="Triple Spiral Valley Pthreads/Thread = 16",label = ["input x t(s)"], lw = 3)
plot!(p, entrada, ic_tsvp16, label = ["IC"])
xlabel!("Tamanho da entrada")
ylabel!("tempo médio(s)")

# %%
tempomedio_fpp32 = [0.2726,0.2522,0.2707,0.1826,0.13633,0.2135,0.4838,0.993,3.0455]
ic_fpp32 = [0.0908,0.0853,0.0916,0.0224,0.00903,0.0112,0.0893,0.104,0.0779]
p = plot(entrada, tempomedio_fpp32, title ="Full Picture Pthreads/Thread = 32",label = ["input x t(s)"], lw = 3)
plot!(p, entrada, ic_fpp32, label = ["IC"])
xlabel!("Tamanho da entrada")
ylabel!("tempo médio(s)")

# %%
tempomedio_svp32 = [0.0800,0.0719,0.0751,0.1142,0.2944,0.3139,0.4842,1.1631,3.8620]
ic_svp32 = [0.0113,0.0124,0.0112,0.0136,0.0845,0.0719,0.0726,0.0760,0.0671]
p = plot(entrada, tempomedio_svp32, title ="Seahorse Valley Pthreads/Thread = 32",label = ["input x t(s)"],  lw = 3)
plot!(p, entrada, ic_svp32, label = ["IC"])
xlabel!("Tamanho da entrada")
ylabel!("tempo médio(s)")

# %%
tempomedio_evp32 = [0.0768,0.06502,0.06530,0.11059,0.14335,0.3637,0.4935,1.1777,3.6320]
ic_evp32 = [0.0142,0.00875,0.00861,0.00661,0.00892,0.0775,0.0652,0.0751,0.0781]
p = plot(entrada, tempomedio_evp32, title ="Elephant Valley Pthreads/Thread = 32",label = ["input x t(s)"], lw = 3)
plot!(p, entrada, ic_evp32, label = ["IC"])
xlabel!("Tamanho da entrada")
ylabel!("tempo médio(s)")

# %%
tempomedio_tsvp32 = [0.1933,0.2385,0.2443,0.2562,0.349,0.2201,0.5060,1.2845,3.9883]
ic_tsvp32 = [0.0801,0.0735,0.0833,0.0700,0.112,0.0232,0.0681,0.0897,0.0746]
p = plot(entrada, tempomedio_tsvp32, title ="Triple Spiral Valley Pthreads/Thread = 32",label = ["input x t(s)"], lw = 3)
plot!(p, entrada, ic_tsvp32, label = ["IC"])
xlabel!("Tamanho da entrada")
ylabel!("tempo médio(s)")

# %% [markdown]
# ## Programa OpenMP

# %%
tempomedio_fpomp = [0.08238,0.2565,0.2362,0.2920,0.1687,0.3779,0.7889,1.7840,5.1519]
ic_fpomp = [0.00269,0.0923,0.0936,0.0953, 0.0176,0.0649,0.0833,0.0824,0.0405]
p = plot(entrada, tempomedio_fpomp, title ="Full Picture OpenMP/Thread = 1",label = ["input x t(s)"], lw = 3)
plot!(p, entrada, ic_fpomp, label = ["IC"])
xlabel!("Tamanho da entrada")
ylabel!("tempo médio(s)")

# %%
tempomedio_svomp = [0.3164,0.0865,0.0957,0.1704,0.4147,0.7785,2.039,6.2551,23.6034]
ic_svomp = [0.0762,0.0144,0.0147,0.0117,0.0746, 0.0789,0.111,0.0529,0.0412]
p = plot(entrada, tempomedio_svomp, title ="Seahorse Valley OpenMP/Thread = 1",label = ["input x t(s)"], lw = 3)
plot!(p, entrada, ic_svomp, label = ["IC"])
xlabel!("Tamanho da entrada")
ylabel!("tempo médio(s)")

# %%
tempomedio_evomp = [0.09710,0.06580,0.0921,0.2783,0.3611,0.6356,1.8660,6.0577,22.6004]
ic_evomp = [0.00827,0.00877,0.0140,0.0825,0.0821,0.0646,0.0682,0.0756,0.0590]
p = plot(entrada, tempomedio_evomp, title ="Elephant Valley OpenMP/Thread = 1",label = ["input x t(s)"], lw = 3)
plot!(p, entrada, ic_evomp, label = ["IC"])
xlabel!("Tamanho da entrada")
ylabel!("tempo médio(s)")

# %%
tempomedio_tsvomp = [0.3206,0.3101,0.2191,0.1496,0.3698,0.8732,2.465,7.0039,26.7995]
ic_tsvomp = [0.0835,0.0881,0.0898,0.0101,0.0733,0.0866,0.126,0.0399,0.0676]
p = plot(entrada, tempomedio_tsvomp, title ="Triple Spiral Valley OpenMP/Thread = 1",label = ["input x t(s)"], lw = 3)
plot!(p, entrada, ic_tsvomp, label = ["IC"])
xlabel!("Tamanho da entrada")
ylabel!("tempo médio(s)")

# %%
tempomedio_fpomp2 = [0.1174,0.06275,0.06634,0.2607,0.3311,0.3463,0.5223,1.385,4.734]
ic_fpomp2 = [0.0122,0.00883,0.00862,0.0857,0.0893,0.0803,0.0735,0.112,0.127]
p = plot(entrada, tempomedio_fpomp2, title ="Full Picture OpenMP/Thread = 2",label = ["input x t(s)"], lw = 3)
plot!(p, entrada, ic_fpomp2, label = ["IC"])
xlabel!("Tamanho da entrada")
ylabel!("tempo médio(s)")

# %%
tempomedio_svomp2 = [0.3139,0.06506,0.2386,0.11798,0.2066,0.5001,1.591,4.2865,14.994]
ic_svomp2 = [0.0849,0.00997,0.0806,0.00855,0.0164,0.0640,0.108,0.0760,0.131]
p = plot(entrada, tempomedio_svomp2, title ="Seahorse Valley OpenMP/Thread = 2",label = ["input x t(s)"], lw = 3)
plot!(p, entrada, ic_svomp2, label = ["IC"])
xlabel!("Tamanho da entrada")
ylabel!("tempo médio(s)")

# %%
tempomedio_evomp2 = [0.3190, 0.2229,0.06918,0.3207,0.3246,0.5225,1.456,3.7687,13.0847]
ic_evomp2 = [0.0860,0.0886,0.00911,0.0794,0.0588,0.0756,0.114,0.0788,0.0693]
p = plot(entrada, tempomedio_evomp2, title ="Elephant Valley OpenMP/Thread = 2",label = ["input x t(s)"], lw = 3)
plot!(p, entrada, ic_evomp2, label = ["IC"])
xlabel!("Tamanho da entrada")
ylabel!("tempo médio(s)")

# %%
tempomedio_tsvomp2 = [0.1185,0.0828,0.0831,0.2142,0.3663,0.5436,1.5895,4.6515,15.925]
ic_tsvomp2 = [0.0138,0.0156,0.0102,0.0404,0.0746,0.0607,0.0916,0.0977,0.109]
p = plot(entrada, tempomedio_tsvomp2, title ="Triple Spiral Valley OpenMP/Thread = 2",label = ["input x t(s)"], lw = 3)
plot!(p, entrada, ic_tsvomp2, label = ["IC"])
xlabel!("Tamanho da entrada")
ylabel!("tempo médio(s)")

# %%
tempomedio_fpomp4 = [0.1309,0.1409,0.06670,0.2607,0.3653,0.2882,0.5856,1.4887,4.3279]
ic_fpomp4 = [0.0200,0.0215,0.00872,0.0828,0.0990,0.0192,0.0864,0.0817,0.0722]
p = plot(entrada, tempomedio_fpomp4, title ="Full Picture OpenMP/Thread = 4",label = ["input x t(s)"], lw = 3)
plot!(p, entrada, ic_fpomp4, label = ["IC"])
xlabel!("Tamanho da entrada")
ylabel!("tempo médio(s)")

# %%
tempomedio_svomp4 = [0.2987,0.1494,0.06106,0.1406,0.2086,0.3303,1.084,2.5565,9.2355,]
ic_svomp4 = [0.0825,0.0796,0.00580,0.0145,0.0107,0.0252,0.107,0.0483,0.0975]
p = plot(entrada, tempomedio_svomp4, title ="Seahorse Valley OpenMP/Thread = 4",label = ["input x t(s)"], lw = 3)
plot!(p, entrada, ic_svomp4, label = ["IC"])
xlabel!("Tamanho da entrada")
ylabel!("tempo médio(s)")

# %%
tempomedio_evomp4 = [0.1320,0.0917,0.221,0.2602,0.2036,0.3816,0.9235,2.4961,9.0312]
ic_evomp4 = [0.0206,0.0142,0.103,0.081,0.0207,0.0679,0.0920,0.0349,0.0984]
p = plot(entrada, tempomedio_evomp4, title ="Elephant Valley OpenMP/Thread = 4",label = ["input x t(s)"], lw = 3)
plot!(p, entrada, ic_evomp4, label = ["IC"])
xlabel!("Tamanho da entrada")
ylabel!("tempo médio(s)")

# %%
tempomedio_tsvomp4 = [0.2608,0.0773,0.055344,0.11387,0.3231,0.2870,1.1192,2.7921,9.4484]
ic_tsvomp4 = [0.0753,0.0134,0.000747,0.00523,0.0725,0.0167,0.0962,0.0857,0.0632]
p = plot(entrada, tempomedio_tsvomp4, title ="Triple Spiral Valley OpenMP/Thread = 4",label = ["input x t(s)"], lw = 3)
plot!(p, entrada, ic_tsvomp4, label = ["IC"])
xlabel!("Tamanho da entrada")
ylabel!("tempo médio(s)")

# %%
tempomedio_fpomp8 = [0.3060,0.0685,0.05596,0.1419,0.1561,0.2467,0.4750,1.315,4.1730]
ic_fpomp8 = [0.0833,0.0109,0.00195,0.0138,0.0100,0.0150,0.0596,0.105,0.0768]
p = plot(entrada, tempomedio_fpomp8, title ="Full Picture OpenMP/Thread = 8",label = ["input x t(s)"], lw = 3)
plot!(p, entrada, ic_fpomp8, label = ["IC"])
xlabel!("Tamanho da entrada")
ylabel!("tempo médio(s)")

# %%
tempomedio_svomp8 = [0.1368,0.2317,0.06598,0.2457,0.3127,0.4490,0.6180,1.9421,6.0486]
ic_svomp8 = [0.0175,0.0913,0.00947,0.0819,0.0756,0.0726,0.0572,0.0876,0.0763]
p = plot(entrada, tempomedio_svomp8, title ="Seahorse Valley OpenMP/Thread = 8",label = ["input x t(s)"], lw = 3)
plot!(p, entrada, ic_svomp8, label = ["IC"])
xlabel!("Tamanho da entrada")
ylabel!("tempo médio(s)")

# %%
tempomedio_evomp8 = [0.1895,0.06403,0.2837,0.1129,0.18176,0.3804,0.6189,1.8257,6.0727]
ic_evomp8 = [0.0223,0.00765,0.0951,0.0106,0.00973,0.0759,0.0716,0.0981,0.0829]
p = plot(entrada, tempomedio_evomp8, title ="Elephant Valley OpenMP/Thread = 8",label = ["input x t(s)"], lw = 3)
plot!(p, entrada, ic_evomp8, label = ["IC"])
xlabel!("Tamanho da entrada")
ylabel!("tempo médio(s)")

# %%
tempomedio_tsvomp8 = [0.3083,0.0728,0.06610,0.2820,0.3035,0.3659,0.7914,2.0570,6.221]
ic_tsvomp8 = [0.0860,0.0126,0.00924,0.0905,0.0905,0.0887,0.0923,0.0873,0.121]
p = plot(entrada, tempomedio_tsvomp8, title ="Triple Spiral Valley OpenMP/Thread = 8",label = ["input x t(s)"], lw = 3)
plot!(p, entrada, ic_tsvomp8, label = ["IC"])
xlabel!("Tamanho da entrada")
ylabel!("tempo médio(s)")

# %%
tempomedio_fpomp16 = [0.1544,0.0768,0.0743,0.1246,0.3121,0.3368,0.4599,0.9646,3.5487]
ic_fpomp16 = [0.0171,0.0105,0.0112,0.0180,0.0869,0.0825,0.0664,0.0665,0.0707]
p = plot(entrada, tempomedio_fpomp16, title ="Full Picture OpenMP/Thread = 16",label = ["input x t(s)"], lw = 3)
plot!(p, entrada, ic_fpomp16, label = ["IC"])
xlabel!("Tamanho da entrada")
ylabel!("tempo médio(s)")

# %%
tempomedio_svomp16 = [0.1429,0.05556,0.2030,0.2539,0.1450,0.2313,0.5347,1.417, 4.453]
ic_svomp16 = [0.0153,0.00109,0.0936,0.0863,0.0138,0.0111,0.0672,0.116,0.131]
p = plot(entrada, tempomedio_svomp16, title ="Seahorse Valley OpenMP/Thread = 16",label = ["input x t(s)"], lw = 3)
plot!(p, entrada, ic_svomp16, label = ["IC"])
xlabel!("Tamanho da entrada")
ylabel!("tempo médio(s)")

# %%
tempomedio_evomp16 = [0.2888,0.05585,0.1438,0.11586,0.1905,0.3687,0.5836,1.3072,4.436]
ic_evomp16 = [0.0885,0.00116,0.0170,0.00734,0.0258,0.0699,0.0667,0.0864,0.112]
p = plot(entrada, tempomedio_evomp16, title ="Elephant Valley OpenMP/Thread = 16",label = ["input x t(s)"], lw = 3)
plot!(p, entrada, ic_evomp16, label = ["IC"])
xlabel!("Tamanho da entrada")
ylabel!("tempo médio(s)")

# %%
tempomedio_tsvomp16 = [0.1668, 0.0874,0.0976,0.1109,0.2418,0.3230,0.5532,1.4352,4.7262]
ic_tsvomp16 = [0.0286,0.0186,0.0248,0.0117,0.0678,0.0805,0.0767,0.0879,0.0915]
p = plot(entrada, tempomedio_tsvomp16, title ="Triple Spiral Valley OpenMP/Thread = 16",label = ["input x t(s)"], lw = 3)
plot!(p, entrada, ic_tsvomp16, label = ["IC"])
xlabel!("Tamanho da entrada")
ylabel!("tempo médio(s)")

# %%
tempomedio_fpomp32 = [16.32,0.0780,0.06703,0.10817,0.3475,0.2427,0.4762, 0.9639,3.093]
ic_fpomp32 = [13.93,0.0127,0.00851,0.00888,0.0747,0.0148,0.0739,0.0725,0.105]
p = plot(entrada, tempomedio_fpomp32, title ="Full Picture OpenMP/Thread = 32",label = ["input x t(s)"], lw = 3)
plot!(p, entrada, ic_fpomp32, label = ["IC"])
xlabel!("Tamanho da entrada")
ylabel!("tempo médio(s)")

# %%
tempomedio_svomp32 = [3.13,0.05969,0.2529,0.305,0.1612,0.3545,0.4873,1.1599,3.820]
ic_svomp32 = [2.03,0.00249,0.0941,0.104,0.0142,0.0815,0.0765,0.0808,0.104]
p = plot(entrada, tempomedio_svomp32, title ="Seahorse Valley OpenMP/Thread = 32",label = ["input x t(s)"], lw = 3)
plot!(p, entrada, ic_svomp32, label = ["IC"])
xlabel!("Tamanho da entrada")
ylabel!("tempo médio(s)")

# %%
tempomedio_evomp32 = [1.654,0.229,0.07409,0.1324, 0.1738,0.3501,0.4403,1.231,3.946]
ic_evomp32 = [0.987,0.108,0.00873,0.0110,0.0213,0.0772,0.0579,0.106,0.106]
p = plot(entrada, tempomedio_evomp32, title ="Elephant Valley OpenMP/Thread = 32",label = ["input x t(s)"], lw = 3)
plot!(p, entrada, ic_evomp32, label = ["IC"])
xlabel!("Tamanho da entrada")
ylabel!("tempo médio(s)")

# %%
tempomedio_tsvomp32 = [0.588,0.07406,0.07037,0.2998,0.2923,0.2213,0.4756,1.1114,3.967]
ic_tsvomp32 = [0.156,0.00862,0.00899,0.0904,0.0786,0.0130,0.0758,0.0703,0.149]
p = plot(entrada, tempomedio_tsvomp32, title ="Triple Spiral Valley OpenMP/Thread = 32",label = ["input x t(s)"], lw = 3)
plot!(p, entrada, ic_tsvomp32, label = ["IC"])
xlabel!("Tamanho da entrada")
ylabel!("tempo médio(s)")
